# %% [markdown]
# # Excel With Copilot
#
#
# 1. Use Copilot to identify and summarize missing values in the dataset.
#
#   - answer from copilot :
#
#     1.  The dataset contains missing values in four columns, each having 10 missing entries, which represents 2.86% of the 350 total records.
#
#       Here is the summary of missing values:
#         ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Use Copilot to fill missing values in the Region and Category columns.
#
# -
# Prompt used : from the column region and category i want you to fill the     empty cells in both the columns with N/A.
#
# Analysis from Excel AI :
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
# Result : ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Fill missing numeric values in the
# Units
# Sold and Unit
# Price columns.
#
# - Prompt used : Fill missing numeric values in the Units Sold and Unit Price columns.
#
# - Result :
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Create a new calculated column Total Revenue.
#
# - Promt used : create a new calculated column in Coumn O named total revenue which contact the product of unit price and unit sold
#
#
#   Result : ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Use Copilot to find the total price of Order ID = 'ORD0123'.
#
# - Prompt used : find the total price of Order ID = 'ORD0123'.
#
# Result : ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Use Copilot to generate a summary chart of average profit by region.
#
# - Prompt Used : generate a summary chart of average profit by region refer the sheet for all the data.
#
#  Result : ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Create a pivot table summarizing total sales by category and region.
#
# - Prompt Used : Create a pivot table in a new sheet summarizing total sales by category and region.
#
#   Result : ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. Build a dashboard combining key KPIs and charts.
#
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9. Use Copilot to generate a summary report
#
# - The dataset contains retail order information for 330 unique orders, spanning from January 01, 2023, to December 16, 2023.
#
# Based on the data, here is a detailed summary report focusing on key performance indicators (KPIs):
# I. Overall Financial KPIs
# The company has generated over $21 million in sales with a profit margin of approximately 24.2%.
#
#     -Total Sales: $21,381,624.96
#     -Total Profit: $5,182,516.49
#     -Total Units Sold: 84,843 units
#     -Average Unit Price: $250.84 (across all orders)
#     -Average Unit Cost: $193.08 (across all orders)
#
# II. Performance by Sales Channel
# The Online channel drives a higher volume of sales and orders, while the Offline channel has a slightly stronger profit performance.
#
# ![image.png](data:image/png;base64,...)
#
# - Sales & Orders: The Online channel accounts for the majority of the total sales ($11.51M) and total orders (175).
#
# - Profitability: Despite lower total sales, the Offline channel generated a higher profit ($2.91M) and achieved a significantly higher profit margin (29.51%) compared to the Online channel's profit margin of 19.72%.
#
# III. Key Segments by Profit and Sales
#
#  A. Category Performance (By Total Profit)
# All categories contribute significantly, with Food leading the profit generation.
#
#  ![image.png](data:image/png;base64,...)
#
#
# #### **B. Regional Performance (By Total Profit)** : The **South** and **North** regions are the top two contributors to overall profit.
#
# ![image.png](data:image/png;base64,...)
#
#
# #### **C. Top 5 Countries (By Total Sales)** : **India** is the highest-performing country by total sales.
#
#
# ![image.png](data:image/png;base64,...)
