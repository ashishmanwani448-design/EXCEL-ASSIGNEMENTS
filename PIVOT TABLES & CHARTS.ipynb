# %% [markdown]
# # PIVOT TABLES & CHARTS

# %% [markdown]
# # Easy Level
#
# 1. What is the purpose of a PivotTable in Excel?
#    - Pivot Tables in Excel are used to summarize, analyze, and reorganize large amounts of data quickly and interactively—without changing the original dataset.
#
# 2. Create a PivotTable to show Total Sales by Region.
#    - ![Screenshot 2025-12-20 195210.png](data:image/png;base64,...)
#
# 3. Apply Conditional Formatting to highlight sales greater than 400.
#   - Step 1 : select the sales Column.
#
#     Step 2 : in Home Tab, in the style menu, Select Conditional Formating.
#
#     ![Screenshot 2025-12-20 195523.png](data:image/png;base64,...)
#
#     Step 3 : select greater than option and add the value “400”.
#
#     Result : ![Screenshot 2025-12-20 195617.png](data:image/png;base64,...)

# %% [markdown]
# # Medium Level
#
# 4. Explain the difference between Sorting and Filtering with an example from this dataset
#    - Sorting :
#    1) Arranges data in a specific order.
#    2) Changes the order of rows
#
#    3) All data remains visible
#    4) Order changes but data remains intact
#
#    - Filtering :
#    1) Displays only selected data based on conditions
#    2) Hides rows that don’t meet criteria
#    3) Only matching data is shown
#    4) Data remains intact; non-matching rows are hidden
#
# 5. Create a PivotChart showing Monthly Sales Trend.
#
#   - ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Use a Slicer to filter data by Product and observe changes in sales.
#  -  STEP 1 : Click inside PivotTable → Insert → Slicer.
#
#     STEP 2 : Select Product field → OK.
#
#     STEP 3 : Use the slicer buttons to filter by Apples, Bananas, etc.
#
#     STEP 4 : Watch how total sales update dynamically.

# %% [markdown]
# # Hard Level
#
# 7. Why are Dashboards important for decision-making in business analysis?
#
#    -  Dashboards provide:
#
#     1) Quick Understanding of Performance : Dashboards present key metrics (KPIs) in charts, graphs, and indicators, allowing managers to see business performance at a glance instead of analyzing long reports.
#
#     2) Better, Data-Driven Decisions : By showing real-time or updated data, dashboards help businesses base decisions on facts, not assumptions—reducing risk and guesswork.
#
#     3) Faster Decision-Making : Since information is centralized and visually summarized, leaders can identify issues or opportunities immediately, saving time and enabling rapid responses.
#
#
#     4) Tracking Goals and KPIs : Dashboards help monitor progress toward targets (sales, revenue, customer retention, costs), making it easy to see whether goals are being met or corrective action is needed.
#
#
# 8. Create a Dashboard that includes:
#
#     Sales by Region (PivotTable + Chart)
#
#     Product Filter (Slicer)
#
#     Monthly Trend (Line Chart)
#
#
#   - ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9. Group dates in the PivotTable into Months and calculate the average sales per month.
#
#    - ![image.png](data:image/png;base64,...)

# %% [markdown]
#    10. Combine Apples and Oranges into one group called Fruits and compare its sales with other products
#
#    - ![image.png](data:image/png;base64,...)
#
#    Fruits” group outperforms other categories — key insight for inventory and marketing focus.
